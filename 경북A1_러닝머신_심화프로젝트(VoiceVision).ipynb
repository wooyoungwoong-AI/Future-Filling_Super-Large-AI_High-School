# %% [markdown]
# # 프로젝트 개요
# 1. 팀원 역할
# 1. 프로젝트 제작 계기
# 1. 목적
# 1. 기술 활용방식
# 1. 구현 코드
# 1. 결과
# 1. 기술 기대 효과
# 1. 느낀 점
#
# ### 팀원역할
# * 우영웅 : 프로젝트 기술 구현(음성 인식, TTS, CNN모델)
# * 이재경 : 피그마로 UI구현 및 모델 학습에 필요한 이미지 데이터 수집
# * 황기성 : 프로젝트 기술 구현 (데이터 제작 및 파인튜닝)
#
# ### 프로젝트 제작 계기
# 모든 사람들이 동등한 기회와 접근성을 가지는 것은 중요한 가치라고 생각합니다. 이 프로젝트는 시각 장애인들이 인공지능의 최신 서비스를 독립적으로 활용할 수 있도록 하기 위해 제작되었습니다.
#
# ### 목적
# 프로젝트의 주요 목적 중 하나는 시각 장애인이 일상 생활에서 더욱 독립적으로 활동할 수 있도록 돕는 것입니다. 시각 장애인은 이미지와 텍스트 정보에 대한 접근에 제한이 있을 수 있으므로 이를 보완하여 필요한 정보를 쉽게 얻을 수 있도록 합니다.
#
# ### 기술 활용 방식
# ChatGPT API와 음성인식, 번역, TTS 기능을 활용하여 prompt를 직접 입력할 필요 없이 음성으로만 ChatGPT의 서비스를 이용할 수 있도록 합니다. 또한 촬영한 이미지 또는 prompt의 입력으로 사용하기 어렵거나 위험한 전자제품 등의 기구에 대한 사용 방법 및 주의할 점을 안내합니다.
#
# ### 구현 코드
# 구현 코드는 해당 텍스트 셀 밑에서 보실 수 있습니다.
#
# ### 결과
# 이번 심화프로젝트에서 서비스의 취지와 맞게 음성인식으로 사용자가 prompt를 타이핑 할 필요 없이 구현을 했으나 Google Colab 개발 환경 에서는 기기 내 마이크 기능을 활용하여 직접 녹음을 할 수 없어 현재는 녹음된 파일로 해당 기능을 대체 하였습니다. 또 TTS 기능도 성공적으로 구현하였고 번역 기능은 papago API를 사용하여 구현하였습니다.
# 번역 기능은 그림 생성을 할 때 prompt가 한국어가 아닌 영어로 사용할 수 있게 끔 하기 위해 구현하였습니다.
#
# ### 기술 기대 효과
# 1. 시각 장애인 들은 gpt처럼 텍스트로 된 정보를 이해하기 힘듭니다. 이런 문제점을 해결할 방안으로 음성인식을 사용해 음성을 gpt의 input으로 받고 텍스트 형태인 output 값을 TTS로 설명해 줍니다. 뉴스, 문서등 다양한 정보를 보다 쉽게 얻을 수 있어 정보 격차 문제를 해결할 수 있습니다.
# 1. 앱 기반 TTS AI는 가전 제품을 볼 수 없어 사용법을 이해하기 힘든 시각 장애인들을 위한 prompt를 작성하고 이를 기반으로 시각 장애인들이 이해하기 힘들고 사고가 발생할 수 있는 위험한 가전 제품의 주의 사항과 사용법을 시각장애인에 눈높이에 맞춰 설명해 줄 수 있습니다.
# 1. 시각 장애인 이라는 제약 사항으로 인해 몇몇 직업에 국한되어 있는 현재의 문제점을 보완해 여러 분야에 도전할 수 있도록 도와줍니다.
# 1. 음성 인식을 통해 글을 작성해 주고 최신 정보를 생성해 주기 때문에 인터넷에서 다른 사람들과 교류하기 쉽게 진입 장벽을 낮추어 사회에 더 활발하게 참여할 수 있게 도와줍니다.
# 1. 인터넷에서 제공하는 정보들은 시각 장애인의 입장에서 이해하기 힘든 내용이 있을 수 있습니다. 이런 문제를 해결하기 위해 시각 장애인의 눈높이에 맞춰 이해하기 쉽게 설명해 시각 장애인들이 자립성을 키울 수 있도록 돕습니다.
#
# ### 느낀 점
# * 우영웅 : 예선 심화프로젝트를 하면서 어떤 주제를 해야 누군가에게 도움을 줄 수 있는 프로젝트를 만들 수 있을 까 고민을 많이 했습니다. 결과적으로 팀원들과 의견을 나누며 좋은 주제를 찾았다 생각을 하고 프로젝트를 만들면서 처음 써보는 기능들에 난관이 많았지만 해쳐나가면서 배울 수 있는 유익했던 기회였던것 같습니다.
#
#
# * 이재경 : 대회에서 인공지능를 활용하는 다양한 활동을 하면서 많은 것을 느꼈고 이러한 경험은 정말로 유익하고 흥미로웠습니다. 특히 심화 프로젝트를 진행하면서, 시각장애인들이 더 나은 삶을 살 수 있도록 도울 수 있는 뜻 깊은 프로젝트였습니다.
#
#
# * 황기성 : 이 프로젝트를 하면서 이전에 배운 내용을 다시 한번 사용해 보면서 복습해 보는 시간이 되었고 시각 장애인 이라는 주제를 선정하고 프로젝트를 수행하니 이들에게 조금이라도 도움이 되었다는 생각에 뿌듯함을 느꼈습니다.
# 또 어려운 부분과 에러가 발생해 힘들기도 했었지만 멘토님의 조언과 다른 방법 등을 찾아 문제를 해결했을 때 기분이 정말 좋았습니다.

# %% [markdown]
# # UI 전체샷

# %% [markdown]
# ![UI전체샷.png](data:image/png;base64,...)

# %% [markdown]
# ### 저희 프로젝트의 UI 구현입니다. 밑의 링크에서 확인 할 수 있습니다.
#
# https://www.figma.com/file/rfgMnw98OxyEGfsb2BxqDs/Untitled?type=design&node-id=28%3A542&mode=design&t=nkBoTt4jn8GWCZJ4-1

# %% [markdown]
# ### Google Colab 환경에서는 직접 녹음이 되지 않아서 음성파일로 대체 하겠습니다 제공된 음성파일을 다운 받으셔도 좋고 직접 녹음한 파일로 사용하여도 좋습니다.  https://drive.google.com/file/d/1lcsoB0aNu6eldaGy_iJz0kGG-unLQFEt/view?usp=sharing (주전자 사용 법에 대해서 알려줘), https://drive.google.com/file/d/1PpGwn38YisKyekd6zsFGVi2Auw1Od3IR/view?usp=sharing (그림 생성), https://drive.google.com/file/d/1q9m183uXGpK-CqsB7-FnP63v_L2F5LEl/view?usp=sharing (고양이를 그려줘), https://drive.google.com/file/d/18vwX6qKntP9640BmuWD1qnnzAnKhC4im/view?usp=drive_link (질문), https://drive.google.com/file/d/1b28jGtmBZRemXO_J2dnCTbt-V-1-Sz37/view?usp=sharing (음성), https://drive.google.com/file/d/1kyH64Ls3LnwRA4g6eWHC9O3sz31_rYQp/view?usp=sharing(사진 촬영)
# ## 다운로드 받으신 후 Colab에 업로드 하셔야 합니다!!

# %% [markdown]
# ## 노트북 환경에서 사진 촬영이 힘들어서 이미지 파일로 대체 하여 진행하겠습니다.
# https://drive.google.com/file/d/1kZ-h6oLNuJcEd0UMFp_Zi-oTxFWFijpq/view?usp=sharing (소화기 이미지)
#
# https://drive.google.com/file/d/1jN0lV2cOAhP4EMtF_G0g7cNhNVapT4b1/view?usp=sharing (저장된 모델 파일)
#
# 마찬가지로 다운로드 받으신 후 Colab에서 업로드 부탁드립니다.

# %% [markdown]
# ### fine tuning에 사용한 데이터셋 입니다. 혹시 참고 하시고 싶다면 밑에 링크를 통해 보셔도 좋습니다.
# https://drive.google.com/file/d/1y5FF65707MiEos_ERsdtewQ7Gq9ZxI3-/view?usp=sharing

# %%
# !pip install SpeechRecognition
# !pip install gTTS
# !pip install playsound
# !pip install openai
# !pip install AudioSegment
# !pip install play

# %%
import speech_recognition as sr
from gtts import gTTS
import playsound
import openai
import time
from pydub import AudioSegment
from pydub.playback import play
import os
import requests
import json
from IPython.display import Audio
from tensorflow import keras
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from PIL import Image

# %% [markdown]
# ### Model Part

# %%
categories = ["가스레인지", "다리미", "소화기", "커피포트"] # 대회 시간에 맞추기 위해 최소한의 카테고리로 구성하였습니다.
model = keras.models.load_model('/content/CNN_Classification.h5') # 학습 후 저장 한 모델 불러오기
def using_model(input_data):
  img = Image.open(input_data)
  img = img.convert("RGB")
  img = img.resize((64, 64))
  data = np.asarray(img)
  X = np.array(data)
  X = X.astype("float") / 256
  X = X.reshape(-1, 64, 64, 3)

  pred = model.predict(X)
  result = [np.argmax(value) for value in pred]
  return categories[result[0]]

# %% [markdown]
# ### TTS Part

# %%
# def speak(text):
#   now = time
#   tts = gTTS(text=text, lang='ko')
#   filename=now.strftime('%Y-%m-%d_%H:%M:%S') + '.mp3'
#   tts.save(filename)
#   print('/content/' + filename)
#   playsound.playsound('/content/' + filename)

# def speak(text):
#   now = time
#   tts = gTTS(text=text, lang='ko')
#   filename=now.strftime('%Y-%m-%d_%H:%M:%S') + '.mp3'
#   tts.save(filename)
#   audio = AudioSegment.from_file(filename, format='mp3')
#   play(audio)

# TTS

def speak(text):
    now = time
    tts = gTTS(text=text, lang='ko')
    filename = now.strftime('%Y-%m-%d_%H:%M:%S') + '.mp3'
    tts.save(filename)
    audio = Audio(filename)
    display.display(audio)

# %% [markdown]
# ### Recording Part

# %%
# 사용자 음성 인식
# ******* 로컬로 실행시키면 오류 없이 실행 시킬 수 있음 (아쉽게도 google colab에서는 실행 불가) **********

# r = sr.Recognizer()
# with sr.Microphone() as source:
#     print('녹음 시작')
#     audio = r.listen(source)
#     print('녹음 끝')

# try:
#     text = r.recognize_google(audio, language='ko')
#     print(text)

# except sr.UnknownValueError:
#     print('인식 실패')

# except sr.RequestError as e:
#     print(f"요청 실패 : {e}")

# %%
r = sr.Recognizer()

# %%
# 음성 인식

def Recording(audio_file):
  try:
    harvard = sr.AudioFile(audio_file)
    with harvard as source:
      audio = r.record(source)
    return r.recognize_google(audio, language='ko_KR')
  except:
    speak('''음성 파일을 불러드리는데 오류가 발생하였습니다.
    음성 파일의 길이나 잡음의 문제일 수 있으니 다시 녹음해 주세요.''')

# %% [markdown]
# Translator Part

# %%
# papago API
# *****번역 기능으로 papago가 한국어를 다른 언어로 번역하는 능력이 뛰어나다 해서 번역 기능으로 papago를 채택하게 되었습니다.*****

# translate 함수 선언
def translator(text):
  client_id = ""
  client_secret = ""
  data = {'text' : text,
          'source' : 'ko',
          'target' : 'en'}
  url = "https://openapi.naver.com/v1/papago/n2mt"
  header = {"X-Naver-Client-id":client_id,
            "X-Naver-client-Secret":client_secret}
  response = requests.post(url, headers=header, data=data)
  rescode = response.status_code
  if(rescode==200):
    send_data = response.json()
    trans_data = (send_data['message']['result']['translatedText'])
    return trans_data
  else:
    print("Error Code:", rescode)

# %%
# test
harvard = sr.AudioFile('/content/create_Image.wav')
with harvard as source:
  audio = r.record(source)
translator(r.recognize_google(audio, language='ko_KR'))

# %% [markdown]
# GPT Part

# %%
openai.api_key = ""

# %%
# 그림 생성에 필요한 것을 불러 드립니다.

from PIL import Image
import requests
from io import BytesIO
import IPython.display as display

def display_image(url) :
  image_response = requests.get(url)
  img = Image.open(BytesIO(image_response.content))

  display.display(img)

# %%
def using_gpt(input_prompt):
  text_response = openai.ChatCompletion.create(
      model="ft:gpt-3.5-turbo-0613:swhub-ai:chat-giseong07:86GUjiXW",
      max_tokens=3000,
      messages=[
          {"role": "system", "content": "시각 장애인에 대해 편견이 없고 시각 장애인이 이해하기 쉽도록 질문에 대답해 주시고 친절하게 설명해 주시는 사회복지사"},
          {"role": "user", "content": input_prompt}])
  return text_response["choices"][0].message.content

# %%
# 음성으로 gpt에게 질문 또는 그림 생성 중 하나를 고를 수 있습니다.
# ******google colab 에서는 직접 녹음이 불가능 해서 음성 파일로 대체 됩니다 주석으로 Recording 부분에 음성 파일을 넣어 실행 부탁드립니다.*****
speak('질문과 그림 생성 중 한가지를 골라 이야기 해주세요. ') # TTS
print('\n녹음 중 : 질문 \n') # 예시 답변
select_input = Recording('/content/create_Image.wav') # Recording
time.sleep(10)

# 질문이라고 이야기 하신 경우 gpt에게 음성으로 프롬프트에 들어갈 말을 해주세요.
if select_input in '질문':
  # 질문 받을 프롬프트를 이미지 또는 음성 둘 중 선택할 수 있습니다.
  speak('프롬프트를 음성으로 입력할지 사진 촬영으로 입력할지 선택하여 이야기 해주세요.') # speak
  print('\n녹음 중 : 사진 촬영 \n') # 예시 답변
  Selection_mode = Recording('/content/take a picture.wav') # Recording
  time.sleep(10)
  if Selection_mode  in '사진 촬영':
    # Colab에서는 임의에 Image 파일로 대체 하겠습니다.
    speak('사진을 촬영해 주세요.') # speak
    input_prompt = using_model('/content/test_data_소화기.jpg') # using_model
    print('Model 예측 완료')
    input_prompt = input_prompt + ' 사용법을 알려줘'
    time.sleep(5)
    speak('텍스트와 TTS를 생성하고 있습니다. 잠시만 기다려주세요.') # Speak
    output_text = using_gpt(input_prompt) # using_gpt
    print(output_text) # text 출력
    speak(output_text) # speak
  else:
    speak('프롬프트에 들어갈 문장을 이야기 해주세요.') # TTS
    print('\n녹음 중 : 주전자 사용 법에 대해서 알려줘 \n') # 예시 답변
    input_prompt = Recording('/content/question2.wav') # Recording
    time.sleep(5)
    speak('텍스트와 TTS를 생성하고 있습니다. 잠시만 기다려주세요.') # Speak
    output_text = using_gpt(input_prompt) # using_gpt
    print(output_text) # text 출력
    speak(output_text) # speak

# 그림 생성이라고 이야기 하신 경우에 프롬프트에 그리고 싶은 것을 말해주시고 프롬프트는 영어로 번역되어 들어갑니다.
if select_input in '그림 생성':
  speak('프롬프트에 들어갈 문장을 이야기 해주세요.') # TTS
  print('\n녹음 중 : 고양이를 그려줘 \n') # 예시 답변
  input_prompt = Recording('/content/image_prompt.wav') # Recording -
  time.sleep(7)
  image_response = openai.Image.create(
    prompt=translator(input_prompt), # Translate
    n=1,
    size="512x512" # 256X256
  )
  display_image(image_response["data"][0]['url']) # Show Image
